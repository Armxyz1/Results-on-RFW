# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
races = ['African','Asian','Caucasian','Indian']
genders = ['Man','Woman']
models = ['AdaFace','ArcFace','ElasticFace','GhostFace','SphereFace']

# %%
for model in models:
    fig = plt.figure()
    for race in races:
        for gender in genders:
            with open(f'{model}/roc/{race}_{gender}_roc.npy','rb') as f:
                fpr  = np.load(f)
                tpr  = np.load(f)
                plt.plot(fpr,tpr,label = f"{race}_{gender}")
    plt.legend()
    plt.title(model)
    plt.xlabel('FPR')
    plt.ylabel('TPR')
    plt.xscale('log')
    plt.savefig(f'./Graphs/Dist/{model}_roc.png')

# %%
for race in races:
    for gender in genders:
        fig = plt.figure()
        for model in models:
            with open(f'{model}/roc/{race}_{gender}_roc.npy','rb') as f:
                fpr  = np.load(f)
                tpr  = np.load(f)
                plt.plot(fpr,tpr,label = model)
        plt.legend()
        plt.title(f"{race}_{gender}")
        plt.xlabel('FPR')
        plt.ylabel('TPR')
        plt.xscale('log')
        plt.savefig(f'./Graphs/Dist/{race}_{gender}_roc.png')
